# %%
import gspread
import pandas as pd

# %%
cred_file = "uplifted-nuance-361712-2c02b06f2038.json"
gc = gspread.service_account(cred_file)
gc

# %%
database = gc.open("Income_Expenses_Data")

# %%
wks = database.worksheet("Sheet1")

# %%
wks
# Out:
# <Worksheet 'Sheet1' id:1990530554>

# %%
data=wks.get_all_records()

# %%
df = pd.DataFrame(data)
df
# Out:
#                     Date     month_year  Account        Category Subcategory  \
# 0      2/3/2022 10:11:00  February-2022       50            Food
# 1      2/3/2022 10:11:00  February-2022      300           Other
# 2      1/3/2022 19:50:00   January-2022       78            Food
# 3      1/3/2022 18:56:00   January-2022       30  Transportation
# 4      1/3/2022 18:22:00   January-2022       67            Food
# ..                   ...            ...      ...             ...         ...
# 272  11/22/2021 14:16:00  November-2021       90            Food
# 273  11/22/2021 14:16:00  November-2021       97            Food
# 274  11/21/2021 17:07:00  November-2021      130  Transportation
# 275  11/21/2021 15:50:00  November-2021      875            Food
# 276  11/21/2021 13:30:00  November-2021     2000           Other
#
#     Note   INR Income/Expense  Amount Currency
# 0           50        Expense      50      INR
# 1          300        Expense     300      INR
# ...

# %%
df.head(10)
# Out:
#                  Date     month_year  Account        Category Subcategory  \
# 0   2/3/2022 10:11:00  February-2022       50            Food
# 1   2/3/2022 10:11:00  February-2022      300           Other
# 2   1/3/2022 19:50:00   January-2022       78            Food
# 3   1/3/2022 18:56:00   January-2022       30  Transportation
# 4   1/3/2022 18:22:00   January-2022       67            Food
# 5   1/3/2022 18:22:00   January-2022     1000           Other
# 6   1/3/2022 18:21:00   January-2022     7500           Other
# 7  2/28/2022 11:56:00  February-2022      400            Food
# 8  2/28/2022 11:45:00  February-2022     2000           Other
# 9  2/27/2022 15:29:00  February-2022      243            Food
#
#   Note   INR Income/Expense  Amount Currency
# 0         50        Expense      50      INR
# 1        300        Expense     300      INR
# 2         78        Expense      78      INR
# 3         30        Expense      30      INR
# ...

# %%
new=df["Income/Expense"]
new[0]
# Out:
# 'Expense'

# %%
len(df)
# Out:
# 277

# %% [markdown]
# ## P1

# %%
value=df['INR']
value[0:4]
# Out:
# 0     50
# 1    300
# 2     78
# 3     30
# Name: INR, dtype: int64

# %%
sum1=0
l=len(df)
for i in range(l):
    if new[i]=="Expense":
        sum1=sum1+value[i]
print('Expense is {}'.format(round(sum1)))
# Out:
# Expense is 59132

# %% [markdown]
# ## P2

# %%
sum2=0
l=len(df)
for i in range(l):
    if new[i]=="Income":
        sum2=sum2+value[i]
print('Income is {}'.format(round(sum2)))
# Out:
# Income is 106554

# %% [markdown]
# ## P3

# %%
len(set(df["Category"]))
# Out:
# 13

# %%
q3 = df["Category"]
q3[0]
# Out:
# 'Food'

# %%
value=df['INR']

# %%
x=list(set(df["Category"]))
length = len(x)
dic={}
for i in x:
    sum=0
    for j in range(len(df)):
        if q3[j]==i:
            sum=sum+value[j]
    print(i,sum)
    dic[i]=sum
# Out:
# Education 1400
# Apparel 3388
# Beauty 196
# Gift 115
# Transportation 9204
# Social Life 2520
# Petty cash 3
# Allowance 50000
# Other 53668
# Household 12188
# Salary 8000
# Food 24604
# Self-development 400

# %%
dic
# Out:
# {'Education': 1400,
#  'Apparel': 3388,
#  'Beauty': 196,
#  'Gift': 115,
#  'Transportation': 9204,
#  'Social Life': 2520,
#  'Petty cash': 3,
#  'Allowance': 50000,
#  'Other': 53668,
#  'Household': 12188,
#  'Salary': 8000,
#  'Food': 24604,
#  'Self-development': 400}

# %% [markdown]
# ## P4

# %%
AVI=sum2-sum1
print("Available for investment",':',AVI)
# Out:
# Available for investment : 47422

# %% [markdown]
# # Gsheet3(Final Report)

# %%
data3 = gc.open("Gsgeet3_FinalSheet")

# %%
sheet = data3.sheet1

# %%
print(sheet.range('B7:B15'))
# Out:
# [<Cell R7C2 'Net Income'>, <Cell R8C2 'Net Expense'>, <Cell R9C2 ''>, <Cell R10C2 'Food'>, <Cell R11C2 'Other'>, <Cell R12C2 'Transportation'>, <Cell R13C2 'Social Life'>, <Cell R14C2 'Household'>, <Cell R15C2 'Apparel'>]

# %%
x=11
for i in sheet.range('B7:B20'):
    print(i.value)
# Out:
# Net Income
# Net Expense
#
# Food
# Other
# Transportation
# Social Life
# Household
# Apparel
# Education
# Salary
# Allowance
# Beauty
# Gift

# %%
print(sheet.acell('A3').row)
# Out:
# 3

# %%
for i in range(7,9):
    print(sheet.row_values(i))
# Out:
# ['', 'Net Income', '106554']
# ['', 'Net Expense', '59132']

# %% [markdown]
# # update

# %%
sheet.row_values(7)
# Out:
# ['', 'Net Income', '106554']

# %%
sheet.find('Food').row
# Out:
# 10

# %% [markdown]
# ## income ( Update)

# %%
r=sheet.find('Net Income').row
c=sheet.find('Net Income').col
print(r,c)
# Out:
# 7 2

# %%
sheet.update_cell(r,c+1,int(sum2))
# Out:
# {'spreadsheetId': '1X-4ddk1ynoMqbpzT0hmn1qc08gk69YsfzS1c8DU1AWE',
#  'updatedRange': 'Sheet1!C7',
#  'updatedRows': 1,
#  'updatedColumns': 1,
#  'updatedCells': 1}

# %% [markdown]
# ## Expense( Update)

# %%
r=sheet.find('Net Expense').row
c=sheet.find('Net Expense').col
print(r,c)
# Out:
# 8 2

# %%
sheet.update_cell(r,c+1,int(sum1))
# Out:
# {'spreadsheetId': '1X-4ddk1ynoMqbpzT0hmn1qc08gk69YsfzS1c8DU1AWE',
#  'updatedRange': 'Sheet1!C8',
#  'updatedRows': 1,
#  'updatedColumns': 1,
#  'updatedCells': 1}

# %% [markdown]
# # category value to Final_Report through py

# %%
dic
# Out:
# {'Education': 1400,
#  'Apparel': 3388,
#  'Beauty': 196,
#  'Gift': 115,
#  'Transportation': 9204,
#  'Social Life': 2520,
#  'Petty cash': 3,
#  'Allowance': 50000,
#  'Other': 53668,
#  'Household': 12188,
#  'Salary': 8000,
#  'Food': 24604,
#  'Self-development': 400}

# %%
for i in dic.keys():
    r=sheet.find(i).row
    c=sheet.find(i).col
    sheet.update_cell(r,c+1,int(dic[i]))

# %% [markdown]
# ## Available invest( Update )

# %%
r=sheet.find('Available for investment').row
c=sheet.find('Available for investment').col

# %%
sheet.update_cell(r,c+1,int(AVI))
# Out:
# {'spreadsheetId': '1X-4ddk1ynoMqbpzT0hmn1qc08gk69YsfzS1c8DU1AWE',
#  'updatedRange': 'Sheet1!C24',
#  'updatedRows': 1,
#  'updatedColumns': 1,
#  'updatedCells': 1}

# %% [markdown]
# ## Extract Investment Profile

# %%
sheet.acell('C27').value
# Out:
# 'Low Risk Taking'

# %% [markdown]
# ## sheet2 (of GSHEET) (Will use at end)

# %%
data3 = gc.open("Gsgeet3_FinalSheet")

# %%
sheet2 = data3.worksheet("Sheet2")

# %%
print(sheet2.range('A2:A7'))
# Out:
# [<Cell R2C1 '1'>, <Cell R3C1 '2'>, <Cell R4C1 '3'>, <Cell R5C1 '4'>, <Cell R6C1 '5'>, <Cell R7C1 '6'>]

# %%
sheet2.find("Investment Company")
# Out:
# <Cell R1C2 'Investment Company'>

# %% [markdown]
# # TASK 2

# %%
data1= gc.open("BSE_data")

# %%
Gsheet = data1.sheet1

# %%
Gsheet
# Out:
# <Worksheet 'Sheet1' id:2073305482>

# %%
Gsheet = data1.worksheet("Sheet1")

# %%
data=Gsheet.get_all_records()
data
# Out:
# [{'Company': 'Sanofi India Ltd.',
#   'BSE code': 500674,
#   'NSE code': 'SANOFI',
#   'ISIN': 'INE058A01010',
#   'Sector': 'Healthcare',
#   'Industry': 'Drugs & Pharma',
#   'Date': '2022-09-05',
#   'Price': '6,158.70',
#   '1 day change(%)': 0.59,
#   '52 Week Low': '6,086.30',
#   '52 Week High': '8,542.75',
#   '3 Year Low': '5,607.00',
#   '3 Year High': '9,300.00',
#   '5 Year Low': '3,901.00',
#   '5 Year High': '9,300.00',
#   'All Time Low': 235.05,
#   'All Time High': '9,300.00',
#   'Market Cap(Cr)': '14,189.17',
#   'Enterprise Value(Cr)': '12,556.76',
#   '1-Week Return': -1.36,
#   '1-Month Return': -6.6,
#   '3-Month Return(%)': -10.19,
#   '1-Year Return(%)': -26.69,
#   '3-Year Return': 0.16,
#   '5-Year Return(%)': 8.88,
#   '10-Year Return(%)': 10.97,
#   'Price to Earnings': 14.49,
#   'Median P/E': 35.91,
#   'Price to Book': 9.75,
#   'Median P/B': 6.71,
#   'Earning Yield(%)': 6.15,
#   'Price earnings to growth': 0.49,
#   'Dividend Yield(%)': 7.95,
# ...

# %%
df = pd.DataFrame(data)
df['Dividend Per Share']
# Out:
# 0      490
# 1      370
# 2      315
# 3      275
# 4      210
#       ...
# 496      0
# 497      0
# 498      0
# 499      0
# 500
# Name: Dividend Per Share, Length: 501, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Company                   501 non-null    object
#  1   BSE code                  501 non-null    int64
#  2   NSE code                  501 non-null    object
#  3   ISIN                      501 non-null    object
#  4   Sector                    501 non-null    object
#  5   Industry                  501 non-null    object
#  6   Date                      501 non-null    object
#  7   Price                     501 non-null    object
#  8   1 day change(%)           501 non-null    float64
#  9   52 Week Low               501 non-null    object
#  10  52 Week High              501 non-null    object
#  11  3 Year Low                501 non-null    object
#  12  3 Year High               501 non-null    object
# ...

# %%
((df['Dividend Per Share']))
# Out:
# 0      490
# 1      370
# 2      315
# 3      275
# 4      210
#       ...
# 496      0
# 497      0
# 498      0
# 499      0
# 500
# Name: Dividend Per Share, Length: 501, dtype: object

# %%
for col_name in df.columns: 
    print(col_name)
# Out:
# Company
# BSE code
# NSE code
# ISIN
# Sector
# Industry
# Date
# Price
# 1 day change(%)
# 52 Week Low
# 52 Week High
# 3 Year Low
# 3 Year High
# 5 Year Low
# 5 Year High
# All Time Low
# All Time High
# Market Cap(Cr)
# Enterprise Value(Cr)
# 1-Week Return
# 1-Month Return
# 3-Month Return(%)
# 1-Year Return(%)
# 3-Year Return
# 5-Year Return(%)
# 10-Year Return(%)
# Price to Earnings
# Median P/E
# Price to Book
# Median P/B
# Earning Yield(%)
# Price earnings to growth
# Dividend Yield(%)
# EV / EBITDA
# Price / Sales
# Price / Cash Flow
# Earning Per Share
# Book Value Per Share
# Cash Flow Per Share
# Free Cash Flow Per Share
# Dividend Per Share

# %%
for i in (df['52 Week Low']):
    if type(i)!=float:
        print('yes')
# Out:
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# yes
# ...

# %%
df.fillna(0)
# Out:
#                                          Company  BSE code    NSE code  \
# 0                              Sanofi India Ltd.    500674      SANOFI
# 1                           Page Industries Ltd.    532827     PAGEIND
# 2    Procter & Gamble Hygiene & Health Care Ltd.    500459        PGHH
# 3                              Abbott India Ltd.    500488  ABBOTINDIA
# 4                                     Bosch Ltd.    500530    BOSCHLTD
# ..                                           ...       ...         ...
# 496                    Westlife Development Ltd.    505533    WESTLIFE
# 497                               Wockhardt Ltd.    532300  WOCKPHARMA
# 498                                Yes Bank Ltd.    532648     YESBANK
# 499                                  Zomato Ltd.    543320      ZOMATO
# 500                              Tata Motors DVR    570001  TATAMTRDVR
#
#              ISIN            Sector                       Industry  \
# ...

# %%
df['Dividend Per Share'] = df['Dividend Per Share'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df['52 Week High'] = df['52 Week High'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df['Price']=df['Price'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %%
df['52 Week Low'] = df['52 Week High'].replace({',':''},regex=True).apply(pd.to_numeric,1)

# %% [markdown]
# ## High Risk Taking

# %%
Com=df[((df['52 Week High'] - df['Price'])/df['52 Week Low'])>0]
Com
# Out:
#                                          Company  BSE code    NSE code  \
# 0                              Sanofi India Ltd.    500674      SANOFI
# 1                           Page Industries Ltd.    532827     PAGEIND
# 2    Procter & Gamble Hygiene & Health Care Ltd.    500459        PGHH
# 3                              Abbott India Ltd.    500488  ABBOTINDIA
# 4                                     Bosch Ltd.    500530    BOSCHLTD
# ..                                           ...       ...         ...
# 496                    Westlife Development Ltd.    505533    WESTLIFE
# 497                               Wockhardt Ltd.    532300  WOCKPHARMA
# 498                                Yes Bank Ltd.    532648     YESBANK
# 499                                  Zomato Ltd.    543320      ZOMATO
# 500                              Tata Motors DVR    570001  TATAMTRDVR
#
#              ISIN            Sector                       Industry  \
# ...

# %%
Com.columns
# Out:
# Index(['Company', 'BSE code', 'NSE code', 'ISIN', 'Sector', 'Industry', 'Date',
#        'Price', '1 day change(%)', '52 Week Low', '52 Week High', '3 Year Low',
#        '3 Year High', '5 Year Low', '5 Year High', 'All Time Low',
#        'All Time High', 'Market Cap(Cr)', 'Enterprise Value(Cr)',
#        '1-Week Return', '1-Month Return', '3-Month Return(%)',
#        '1-Year Return(%)', '3-Year Return', '5-Year Return(%)',
#        '10-Year Return(%)', 'Price to Earnings', 'Median P/E', 'Price to Book',
#        'Median P/B', 'Earning Yield(%)', 'Price earnings to growth',
#        'Dividend Yield(%)', 'EV / EBITDA', 'Price / Sales',
#        'Price / Cash Flow', 'Earning Per Share', 'Book Value Per Share',
#        'Cash Flow Per Share', 'Free Cash Flow Per Share',
#        'Dividend Per Share'],
#       dtype='object')

# %%
HRT=Com[Com['Market Cap(Cr)']<6000]
HRT
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [64], in <cell line: 1>()
# ----> 1 HRT=Com[Com['Market Cap(Cr)']<6000]
#       2 HRT
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:48, in OpsMixin.__lt__(self, other)
#      46 @unpack_zerodim_and_defer("__lt__")
#      47 def __lt__(self, other):
# ---> 48     return self._cmp_method(other, operator.lt)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:5623, in Series._cmp_method(self, other, op)
#    5620 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    5622 with np.errstate(all="ignore"):
# ...

# %%
HRT=HRT[Com['10-Year Return(%)']<8]
HRT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [65], in <cell line: 1>()
# ----> 1 HRT=HRT[Com['10-Year Return(%)']<8]
#       2 HRT
#
# NameError: name 'HRT' is not defined

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Company                   501 non-null    object
#  1   BSE code                  501 non-null    int64
#  2   NSE code                  501 non-null    object
#  3   ISIN                      501 non-null    object
#  4   Sector                    501 non-null    object
#  5   Industry                  501 non-null    object
#  6   Date                      501 non-null    object
#  7   Price                     501 non-null    float64
#  8   1 day change(%)           501 non-null    float64
#  9   52 Week Low               501 non-null    float64
#  10  52 Week High              501 non-null    float64
#  11  3 Year Low                501 non-null    object
#  12  3 Year High               501 non-null    object
# ...

# %%
comHRT=(HRT.sort_values('Dividend Per Share',ascending=False).head(5))['Company']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [67], in <cell line: 1>()
# ----> 1 comHRT=(HRT.sort_values('Dividend Per Share',ascending=False).head(5))['Company']
#
# NameError: name 'HRT' is not defined

# %%
list1=[]
for i in comHRT:
    list1.append(i)
print(list1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [68], in <cell line: 2>()
#       1 list1=[]
# ----> 2 for i in comHRT:
#       3     list1.append(i)
#       4 print(list1)
#
# NameError: name 'comHRT' is not defined

# %% [markdown]
# ## 	Risk Taking

# %%
Com=df[((df['52 Week High']-df['Price'])/df['52 Week Low'])>0]
Com
# Out:
#                                          Company  BSE code    NSE code  \
# 0                              Sanofi India Ltd.    500674      SANOFI
# 1                           Page Industries Ltd.    532827     PAGEIND
# 2    Procter & Gamble Hygiene & Health Care Ltd.    500459        PGHH
# 3                              Abbott India Ltd.    500488  ABBOTINDIA
# 4                                     Bosch Ltd.    500530    BOSCHLTD
# ..                                           ...       ...         ...
# 496                    Westlife Development Ltd.    505533    WESTLIFE
# 497                               Wockhardt Ltd.    532300  WOCKPHARMA
# 498                                Yes Bank Ltd.    532648     YESBANK
# 499                                  Zomato Ltd.    543320      ZOMATO
# 500                              Tata Motors DVR    570001  TATAMTRDVR
#
#              ISIN            Sector                       Industry  \
# ...

# %%
RT = Com[(Com['Market Cap(Cr)']>4000) & (Com['Market Cap(Cr)']<8000)]
RT
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [70], in <cell line: 1>()
# ----> 1 RT = Com[(Com['Market Cap(Cr)']>4000) & (Com['Market Cap(Cr)']<8000)]
#       2 RT
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:5623, in Series._cmp_method(self, other, op)
#    5620 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# ...

# %%
RT = RT[(RT['10-Year Return(%)']>8) & (RT['10-Year Return(%)']<10) ]
RT

# %%
comRT=(RT.sort_values('Dividend Per Share',ascending=False).head(5))['Company']

# %%
comRT

# %%
list2=[]
for i in comRT:
    list2.append(i)
list2

# %% [markdown]
# ## 	Moderate Risk Taking

# %%
Com=df[((df['52 Week High']-df['Price'])/df['52 Week Low'])>0]
Com

# %%
MRT = Com[(Com['Market Cap(Cr)']>8000) & (Com['Market Cap(Cr)']<12000)]
MRT

# %%
MRT = MRT[(MRT['10-Year Return(%)']>15) & (MRT['10-Year Return(%)']<20) ]
MRT

# %%
comMRT=(MRT.sort_values('Dividend Per Share',ascending=False).head(5))['Company']

# %%
comMRT

# %%
list3=[]
for i in comMRT:
    list3.append(i)
list3

# %% [markdown]
# ## Low Risk Taking

# %%
Com=df[((df['52 Week High']-df['Price'])/df['52 Week Low'])>0]
Com

# %%
LRT = Com[(Com['Market Cap(Cr)']>12000)]
LRT

# %%
LRT = LRT[(LRT['10-Year Return(%)']>20)]
LRT

# %%
comLRT=(LRT.sort_values('Dividend Per Share',ascending=False).head(5))['Company']

# %%
comLRT

# %%
list4=[]
for i in comLRT:
    list4.append(i)
list4

# %% [markdown]
# ## Extract Investment Profile

# %%
Investment_Profile = sheet.acell('C27').value
Investment_Profile

# %% [markdown]
# ## sheet2 (of FinalSheet)

# %%
data3 = gc.open("Gsheet3")

# %%
sheet2 = data3.worksheet("Sheet2")

# %%
print(sheet2.range('A2:A7'))

# %% [markdown]
# ### Making a Dict for company

# %%
dic = {'High Risk Taking':list1,'Risk Taking':list2,'Moderate Risk Taking':list3,
      'Low Risk Taking':list4}

# %%
Investment_Profile

show = dic[Investment_Profile]
show

# %% [markdown]
# ## Investment Company

# %%
r=sheet2.find('Investment Company').row
c=sheet2.find('Investment Company').col
r,c

# %%
row=r+1
col=c
for i in show:
    sheet2.update_cell(row,col,i)
    row+=1

# %% [markdown]
# ## Amount to be invested

# %%
x = AVI/5

# %%
x

# %%
r=sheet2.find('Amount to be invested').row
c=sheet2.find('Amount to be invested').col
r,c

# %%
for i in range(r+1,r+6):
    sheet2.update_cell(i,c,int(x))

# %% [markdown]
# # df

# %%
for i in df['3 Year Low']:
        if type(i)==str:
           i=0
           print(i)

# %%
for i in df['3 Year Low']:
    print(i)

# %%
sheet9 = new.worksheet("Sheet1")

# %%
sheet9.get_all_records()

# %%
ndf = pd.DataFrame(sheet9.get_all_records())

# %%
ndf['Industry']=='Drugs & Pharma'
